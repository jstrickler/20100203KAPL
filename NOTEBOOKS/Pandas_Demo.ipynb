# %% [markdown]
# # Pandas Demo

# %% [markdown]
# ### Standard imports

# %%
import pandas as pd

# %% [markdown]
# ### Reading data into a dataframe

# %%
df = pd.read_csv('../DATA/airport_boardings.csv', index_col=1, thousands='.')
df.head()
# Out:
#                                                 Airport  2001 Rank  \
# Code
# ATL   Atlanta, GA (Hartsfield-Jackson Atlanta Intern...          1
# ORD          Chicago, IL (Chicago O'Hare International)          2
# DFW        Dallas, TX (Dallas/Fort Worth International)          3
# DEN                   Denver, CO (Denver International)          6
# LAX         Los Angeles, CA (Los Angeles International)          4
#
#       2001 Total  2010 Rank  2010 Total  2011 Rank       Total  \
# Code
# ATL   36,384,264          1  42,655,392          1  33,034,788
# ORD   28,626,694          2  30,033,313          2  22,367,052
# DFW   25,198,256          3  26,785,739          3  20,430,281
# DEN   16,397,390          4  24,965,553          4  19,190,341
# LAX   22,873,307          5  22,860,849          5  18,379,418
#
#       Percent change 2001-2011  Percent change 2010-2011
# Code
# ATL                        -92                      -226
# ORD                       -219                      -255
# DFW                       -189                      -237
# DEN                        170                      -231
# LAX                       -196                      -196

# %% [markdown]
# ### Using .describe() for a data overview

# %%
df.describe()
# Out:
#        2001 Rank  2010 Rank  2011 Rank  Percent change 2001-2011  \
# count  50.000000  50.000000   50.00000                 50.000000
# mean   26.460000  25.580000   25.50000               -126.780000
# std    15.761242  14.708168   14.57738                217.998904
# min     1.000000   1.000000    1.00000               -650.000000
# 25%    13.250000  13.250000   13.25000               -224.250000
# 50%    26.500000  25.500000   25.50000               -143.000000
# 75%    38.750000  37.750000   37.75000                -46.000000
# max    59.000000  51.000000   50.00000                414.000000
#
#        Percent change 2010-2011
# count                 50.000000
# mean                -237.580000
# std                   24.359627
# min                 -322.000000
# 25%                 -252.750000
# 50%                 -236.500000
# 75%                 -220.750000
# max                 -195.000000

# %% [markdown]
# ### using .info() to get data use details

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, ATL to IND
# Data columns (total 9 columns):
# Airport                     50 non-null object
# 2001 Rank                   50 non-null int64
# 2001 Total                  50 non-null object
# 2010 Rank                   50 non-null int64
# 2010 Total                  50 non-null object
# 2011 Rank                   50 non-null int64
#  Total                      50 non-null object
# Percent change 2001-2011    50 non-null int64
# Percent change 2010-2011    50 non-null int64
# dtypes: int64(5), object(4)
# memory usage: 3.9+ KB

# %% [markdown]
# ### Getting real memory use

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, ATL to IND
# Data columns (total 9 columns):
# Airport                     50 non-null object
# 2001 Rank                   50 non-null int64
# 2001 Total                  50 non-null object
# 2010 Rank                   50 non-null int64
# 2010 Total                  50 non-null object
# 2011 Rank                   50 non-null int64
#  Total                      50 non-null object
# Percent change 2001-2011    50 non-null int64
# Percent change 2010-2011    50 non-null int64
# dtypes: int64(5), object(4)
# memory usage: 19.5 KB

# %% [markdown]
# ### Read data from the Titanic Disaster

# %%
titanic = pd.read_csv('../DATA/titanic3.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.describe(include='int')
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
titanic.describe(include='all')
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881135
# std        0.837836     0.486055                   NaN   NaN    14.413500
# min        1.000000     0.000000                   NaN   NaN     0.166700
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# count   1309.000000  1309.000000      1309  1308.000000          295     1307
# unique          NaN          NaN       929          NaN          186        3
# top             NaN          NaN  CA. 2343          NaN  C23 C25 C27        S
# freq            NaN          NaN        11          NaN            6      914
# mean       0.498854     0.385027       NaN    33.295479          NaN      NaN
# std        1.041658     0.865560       NaN    51.758668          NaN      NaN
# min        0.000000     0.000000       NaN     0.000000          NaN      NaN
# 25%        0.000000     0.000000       NaN     7.895800          NaN      NaN
# 50%        0.000000     0.000000       NaN    14.454200          NaN      NaN
# 75%        1.000000     0.000000       NaN    31.275000          NaN      NaN
# max        8.000000     9.000000       NaN   512.329200          NaN      NaN
#
#        boat        body     home.dest
# count   486  121.000000           745
# unique   27         NaN           369
# top      13         NaN  New York, NY
# freq     39         NaN            64
# mean    NaN  160.809917           NaN
# std     NaN   97.696922           NaN
# min     NaN    1.000000           NaN
# 25%     NaN   72.000000           NaN
# 50%     NaN  155.000000           NaN
# 75%     NaN  256.000000           NaN
# max     NaN  328.000000           NaN

# %% [markdown]
# <!-- TODO: add summarizing columns, pivot, groupby, hierarchical, etc. -->

# %% [markdown]
# ### Only describe objects (text)

# %% [markdown]
# Note the high ratio of count to unique for *sex*, *embarked*, and *boat*. These are prime opportunities to save memory by using categoricals.

# %%
titanic.describe(include='O')
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1307  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      914   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %% [markdown]
# #### more to come....
# <!-- TODO: add summarizing columns/rows, pivot, groupby, multiindexing, boolean masking -->
